# %% [markdown]
# # Results FCBG Connectome Registration
#
# Visualisation of metabolite concentration maps (MRSI) overlaid on the T1w UNI-DEN background.

# %%
# %run -i main.py
# Out:
#   [sum] sub-01: saved sub-01_ses-01_acq-OrigRes_desc-AllMetabSum_mrsi.nii.gz  (38 maps summed)
#   [t1w-ds] sub-01: already exists  sub-01_ses-01_acq-MRSIres_T1w.nii.gz
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-Registered_mrsi.nii.gz
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-FullRes_desc-Registered_mrsi.nii.gz
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-RegisteredSum_mrsi.nii.gz
#   [reg] applying pre-computed transforms (skipping optimisation)
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-SumViaBestSNRXfm_mrsi.nii.gz
#   [reg] applying pre-computed transforms (skipping optimisation)
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BestSNRViaSumXfm_mrsi.nii.gz
# Best-coverage metabolite: MM14addLip13aaddLip13baddMM12  (49036 voxels)
#   [reg] saved registered MRSI: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BestCoverageReg_mrsi.nii.gz
#   [inv-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInSum_T1w.nii.gz
#   [inv-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInGly_T1w.nii.gz
#   [inv-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wViaSumInGly_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInGlyWeighted_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInSumWeighted_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wViaWSumInGly_T1w.nii.gz
#   [reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-WaterRegistered_T1w.nii.gz
#   [bet] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-FullRes_desc-Brain_T1w.nii.gz
#   [fast] already exists: sub-01_ses-01_acq-FullRes_desc-Brain_T1w_seg_seg.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BrainT1wInGly_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BrainT1wInSum_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BrainT1wViaSumInGly_T1w.nii.gz
#   [sum-ras] sub-01: already exists  sub-01_ses-01_acq-OrigRes_desc-AllMetabSumRAS_mrsi.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInWaterViaReg11_T1w.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-T1wInWaterReg18_T1w.nii.gz
#   [xfm] already exists: sub-01_ses-01_acq-MRSIres_desc-BrainMaskReg_T1w.nii.gz
#   [xfm] already exists: sub-01_ses-01_acq-MRSIres_desc-FreesurferMaskReg_T1w.nii.gz
#   [xfm] already exists: sub-01_ses-01_acq-MRSIres_desc-WaterMaskReg_mrsi.nii.gz
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BrainT1wInSumRAS_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-2HGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AlaReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AscReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AspReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-CrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-CraddPCrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GABAReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GPCReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GPCaddPChReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GSHReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlcReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlnReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GluReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GluaddGlnReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-InsReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-InsaddGlyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-LacReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13aReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13aaddLip13bReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13bReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM12Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM14Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM14addLip13aaddLip13baddMM12Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM17Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM20addLip20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAaddNAAGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-PChReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-PCrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-ScyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-SerReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-TauReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-ThrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-minusCrCH2Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-WaterSignalReg17_T1w.nii.gz
#
# Registration quality metrics (Reg-17 total pipeline):
#   MM12                          coverage=0.998  NCC=+0.1252  NMI=0.0171
#   Tau                           coverage=0.997  NCC=-0.1162  NMI=0.0158
#   minusCrCH2                    coverage=0.998  NCC=-0.1079  NMI=0.0167
#   PCr                           coverage=0.988  NCC=-0.1050  NMI=0.0164
#   Scy                           coverage=0.982  NCC=-0.1040  NMI=0.0059
#   CraddPCr                      coverage=0.999  NCC=-0.0971  NMI=0.0167
#   Asc                           coverage=0.973  NCC=-0.0958  NMI=0.0060
#   GSH                           coverage=0.996  NCC=-0.0945  NMI=0.0152
#   Asp                           coverage=0.999  NCC=-0.0911  NMI=0.0165
#   InsaddGly                     coverage=0.999  NCC=-0.0896  NMI=0.0156
#   Gln                           coverage=0.981  NCC=-0.0821  NMI=0.0090
#   Ins                           coverage=0.998  NCC=-0.0814  NMI=0.0167
#   PCh                           coverage=0.989  NCC=-0.0813  NMI=0.0136
#   GluaddGln                     coverage=0.999  NCC=-0.0695  NMI=0.0172
#   Gly                           coverage=0.990  NCC=-0.0680  NMI=0.0064
#   GPCaddPCh                     coverage=0.999  NCC=-0.0657  NMI=0.0144
#   Glu                           coverage=0.998  NCC=-0.0648  NMI=0.0177
#   Lac                           coverage=0.744  NCC=-0.0647  NMI=0.0063
#   Cr                            coverage=0.998  NCC=-0.0620  NMI=0.0102
#   Thr                           coverage=0.395  NCC=-0.0600  NMI=0.0081
#   Ala                           coverage=0.718  NCC=-0.0584  NMI=0.0072
#   NAA                           coverage=0.998  NCC=-0.0583  NMI=0.0174
#   MM17                          coverage=0.999  NCC=-0.0514  NMI=0.0141
#   Ser                           coverage=0.979  NCC=-0.0512  NMI=0.0065
#   GABA                          coverage=0.999  NCC=-0.0489  NMI=0.0155
#   2HG                           coverage=0.622  NCC=-0.0454  NMI=0.0081
#   NAAaddNAAG                    coverage=0.999  NCC=-0.0422  NMI=0.0179
#   MM14addLip13aaddLip13baddMM12  coverage=0.999  NCC=+0.0316  NMI=0.0181
#   WaterSignal                   coverage=1.000  NCC=+0.0228  NMI=0.0143
#   Lip13a                        coverage=0.481  NCC=-0.0209  NMI=0.0054
#   Glc                           coverage=0.935  NCC=-0.0193  NMI=0.0082
#   Lip13b                        coverage=0.497  NCC=+0.0188  NMI=0.0102
#   MM20addLip20                  coverage=0.601  NCC=+0.0170  NMI=0.0079
#   NAAG                          coverage=0.995  NCC=+0.0139  NMI=0.0147
#   GPC                           coverage=0.987  NCC=-0.0108  NMI=0.0111
#   Lip13aaddLip13b               coverage=0.698  NCC=-0.0096  NMI=0.0052
#   MM14                          coverage=0.998  NCC=+0.0070  NMI=0.0175
#   Lip20                         coverage=0.499  NCC=+0.0044  NMI=0.0075
#   MM20                          coverage=0.489  NCC=-0.0005  NMI=0.0088
# [weighted-reg] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/sub-01_ses-01_acq-MRSIres_desc-BrainT1wInSumRAS-FSMask_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-2HGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AlaReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AscReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-AspReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-CrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-CraddPCrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GABAReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GPCReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GPCaddPChReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GSHReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlcReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlnReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GluReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GluaddGlnReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-GlyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-InsReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-InsaddGlyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-LacReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13aReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13aaddLip13bReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip13bReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-Lip20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM12Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM14Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM14addLip13aaddLip13baddMM12Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM17Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-MM20addLip20Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-NAAaddNAAGReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-PChReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-PCrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-ScyReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-SerReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-TauReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-ThrReg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-minusCrCH2Reg17_T1w.nii.gz
#   [reg17] already exists: /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/data/output/final_reg/sub-01_ses-01_acq-MRSIres_desc-WaterSignalReg17_T1w.nii.gz
#
# Registration quality metrics (Reg-17 total pipeline):
#   MM12                          coverage=0.998  NCC=+0.1252  NMI=0.0171
#   Tau                           coverage=0.997  NCC=-0.1162  NMI=0.0158
#   minusCrCH2                    coverage=0.998  NCC=-0.1079  NMI=0.0167
#   PCr                           coverage=0.988  NCC=-0.1050  NMI=0.0164
#   Scy                           coverage=0.982  NCC=-0.1040  NMI=0.0059
#   CraddPCr                      coverage=0.999  NCC=-0.0971  NMI=0.0167
#   Asc                           coverage=0.973  NCC=-0.0958  NMI=0.0060
#   GSH                           coverage=0.996  NCC=-0.0945  NMI=0.0152
#   Asp                           coverage=0.999  NCC=-0.0911  NMI=0.0165
#   InsaddGly                     coverage=0.999  NCC=-0.0896  NMI=0.0156
#   Gln                           coverage=0.981  NCC=-0.0821  NMI=0.0090
#   Ins                           coverage=0.998  NCC=-0.0814  NMI=0.0167
#   PCh                           coverage=0.989  NCC=-0.0813  NMI=0.0136
#   GluaddGln                     coverage=0.999  NCC=-0.0695  NMI=0.0172
#   Gly                           coverage=0.990  NCC=-0.0680  NMI=0.0064
#   GPCaddPCh                     coverage=0.999  NCC=-0.0657  NMI=0.0144
#   Glu                           coverage=0.998  NCC=-0.0648  NMI=0.0177
#   Lac                           coverage=0.744  NCC=-0.0647  NMI=0.0063
#   Cr                            coverage=0.998  NCC=-0.0620  NMI=0.0102
#   Thr                           coverage=0.395  NCC=-0.0600  NMI=0.0081
#   Ala                           coverage=0.718  NCC=-0.0584  NMI=0.0072
#   NAA                           coverage=0.998  NCC=-0.0583  NMI=0.0174
#   MM17                          coverage=0.999  NCC=-0.0514  NMI=0.0141
#   Ser                           coverage=0.979  NCC=-0.0512  NMI=0.0065
#   GABA                          coverage=0.999  NCC=-0.0489  NMI=0.0155
#   2HG                           coverage=0.622  NCC=-0.0454  NMI=0.0081
#   NAAaddNAAG                    coverage=0.999  NCC=-0.0422  NMI=0.0179
#   MM14addLip13aaddLip13baddMM12  coverage=0.999  NCC=+0.0316  NMI=0.0181
#   WaterSignal                   coverage=1.000  NCC=+0.0228  NMI=0.0143
#   Lip13a                        coverage=0.481  NCC=-0.0209  NMI=0.0054
#   Glc                           coverage=0.935  NCC=-0.0193  NMI=0.0082
#   Lip13b                        coverage=0.497  NCC=+0.0188  NMI=0.0102
#   MM20addLip20                  coverage=0.601  NCC=+0.0170  NMI=0.0079
#   NAAG                          coverage=0.995  NCC=+0.0139  NMI=0.0147
#   GPC                           coverage=0.987  NCC=-0.0108  NMI=0.0111
#   Lip13aaddLip13b               coverage=0.698  NCC=-0.0096  NMI=0.0052
#   MM14                          coverage=0.998  NCC=+0.0070  NMI=0.0175
#   Lip20                         coverage=0.499  NCC=+0.0044  NMI=0.0075
#   MM20                          coverage=0.489  NCC=-0.0005  NMI=0.0088

# %%
from data_utils import (
    img_info,
    rank_metabolites_by_snr,
    segment_t1w,segment_t1w_atlas)
from registration_utils import (
    register_t1w_to_mrsi_weighted,
    apply_transform_to_metabolite,
    apply_transform_all_metabolites,
    compute_registration_metrics,
    
)
from plot_utils import (
    plot_single_overlay,
    plot_support_mask,
    plot_coverage_grid,
    plot_mrsi_mosaic,
    plot_mrsi_combined,
    build_coverage_widget,
    plot_t1w_mrs_comparison,
    plot_snr_ranking,
    plot_water_mask_comparison,
    plot_registration_comparison,
    plot_registration_methods_comparison,
    plot_registration_target_comparison,
    plot_coverage_registration_comparison,
    compare_registration_coverage,
    plot_sum_registration_comparison,
    plot_inverse_registration_panels,
    compare_inverse_registration_pair,
    plot_total_pipeline_comparison,
    plot_total_pipeline_mask_comparison,
    plot_registration_metrics,
    plot_pipeline_metrics_comparison,
    plot_final_registration_mosaic,
    plot_segmentation,
    plot_atlas_segmentation,
    plot_mrsi_sum_mask_contours,
    plot_mask_coverage_comparaison,
)

# %% [markdown]
# ## 1 – Sanity check: image shapes & voxel sizes

# %%
img_info(t1w_img,     "T1w UNI-DEN")
img_info(mrs_example, f"MRS – {mrs_files[0]}")
# Out:
# T1w UNI-DEN
#   shape      : (224, 272, 288)
#   voxel size : [0.8   0.799 0.799] mm
#   dtype      : int16
#
# MRS – sub-01_ses-01_acq-OrigRes_desc-2HG_mrsi.nii.gz
#   shape      : (74, 74, 37)
#   voxel size : [2.973 2.973 2.973] mm
#   dtype      : float32

# %% [markdown]
# ## 2 – Single metabolite overlay on T1w
#
# `plot_single_overlay` canonicalizes orientations, resamples MRSI to T1 grid, and plots 3 orthogonal views.
# Change `METABOLITE` to any label available in `mrs_files`.

# %%
METABOLITE = "NAA"   # change to any metabolite label (e.g. "Cr", "Glu", "GABA")
match = [f for f in mrs_files if f"desc-{METABOLITE}_" in f]
if not match:
    print(f"No file found for metabolite '{METABOLITE}'")
else:
    print(f"Showing: {match[0]}")
    plot_single_overlay(match[0], T1W_PATH, MRS_DIR, subj=SUBJ)
# Out:
# Showing: sub-01_ses-01_acq-OrigRes_desc-NAA_mrsi.nii.gz
#   Brain coverage: 18.6%

# %% [markdown]
# ## 3 – Coverage check:
#
# Overlay several metabolite maps on the T1w in a single figure  so we can directly compare spatial coverage across metabolites.

# %%
COVERAGE_MAPS = [
    f"{SUBJ}_{SES}_acq-OrigRes_desc-NAA_mrsi.nii.gz",
    f"{SUBJ}_{SES}_acq-OrigRes_desc-Cr_mrsi.nii.gz",
    f"{SUBJ}_{SES}_acq-OrigRes_desc-Glu_mrsi.nii.gz",
    f"{SUBJ}_{SES}_acq-OrigRes_desc-Ins_mrsi.nii.gz",
    f"{SUBJ}_{SES}_acq-OrigRes_desc-GABA_mrsi.nii.gz",
    f"{SUBJ}_{SES}_acq-OrigRes_desc-GluaddGln_mrsi.nii.gz",
]
plot_coverage_grid(COVERAGE_MAPS, MRS_DIR, T1W_PATH, subj=SUBJ)

# %% [markdown]
# ## 5 – Support mask: pure binary spatial footprint
#
# Binary mask of where signal exists, overlaid on the T1w.

# %%
plot_support_mask(
    f"{SUBJ}_{SES}_acq-OrigRes_desc-Glu_mrsi.nii.gz",
    T1W_PATH, MRS_DIR, subj=SUBJ,
)
# Out:
#   Brain coverage: 14.1%
# 0.1414142215021152

# %% [markdown]
# ## 7 – Sum of all metabolite maps (native MRS space)

# %%
# visualise all 3 orthogonal centre slices side by side
plot_mrsi_combined([SUM_NAME], MRS_DIR, subj=SUBJ, cmaps=["hot"], alpha=0.9)

# %% [markdown]
# ## 8 – Downsampled T1w at MRSI resolution
#
# The T1w UNI-DEN image is resampled to the exact voxel grid of the MRSI concentration maps.

# %%
print("=== Downsampled T1w ===")
img_info(t1w_ds_img, f"T1w @ MRS res  ({T1W_DS_NAME})")
img_info(mrs_example, f"MRS ref        ({mrs_files[0]})")

# pick NAA as the representative metabolite for the overlay comparison
_ref_metab = f"{SUBJ}_{SES}_acq-OrigRes_desc-NAA_mrsi.nii.gz"
import nibabel as nib, os
_mrs_img = nib.load(os.path.join(MRS_DIR, _ref_metab))

plot_t1w_mrs_comparison(
    t1w_ds_img,
    _mrs_img,
    subj=SUBJ,
    mrs_label="NAA",
    )
# Out:
# === Downsampled T1w ===
# T1w @ MRS res  (sub-01_ses-01_acq-MRSIres_T1w.nii.gz)
#   shape      : (74, 74, 37)
#   voxel size : [2.973 2.973 2.973] mm
#   dtype      : float32
#
# MRS ref        (sub-01_ses-01_acq-OrigRes_desc-2HG_mrsi.nii.gz)
#   shape      : (74, 74, 37)
#   voxel size : [2.973 2.973 2.973] mm
#   dtype      : float32

# %% [markdown]
# ## 9 – Best-SNR metabolite map
#
# All `acq-OrigRes` concentration maps are ranked by their mean VoxelSNR  the scanner derived per voxel SNR map (`desc-VoxelSNR_mrsi`) averaged over the support mask of each metabolite.

# %%
# rank all metabolites by SNR using the scanner-provided VoxelSNR map
snr_records = rank_metabolites_by_snr(MRS_DIR, subj=SUBJ, ses=SES)

# bar chart: mean/median SNR + coverage for the top-20 maps
plot_snr_ranking(snr_records, top_n=10, highlight_best=3)
# Out:
# Top-3 metabolites by mean VoxelSNR:
#   # 1  Gly                        mean_SNR=4.86  median_SNR=4.00  n_voxels=38,015  CV=9.187
#   # 2  PCr                        mean_SNR=4.84  median_SNR=4.00  n_voxels=38,708  CV=4.719
#   # 3  PCh                        mean_SNR=4.79  median_SNR=4.00  n_voxels=39,631  CV=2.344

# %%
# visualise the best-SNR map and the top-3 together
best = snr_records[0]
top3 = [r["filename"] for r in snr_records[:3]]

print(f"Best SNR metabolite: {best['metabolite']}  (mean_SNR={best['mean_snr']:.2f})")

# mosaic: peak axial slice for each of the top-3 maps
plot_mrsi_mosaic(top3, MRS_DIR, subj=SUBJ, cmap="hot", cols=3)
# Out:
# Best SNR metabolite: Gly  (mean_SNR=4.86)

# %% [markdown]
# ## 10 – Water mask: raw vs hole-filled comparison

# %%
plot_water_mask_comparison(water_img, water_mask, subj=SUBJ, ses=SES)
# Out:
# Raw mask voxels   : 64,117
# Filled mask voxels: 64,170
# Holes recovered   : 53  (0.08% of filled mask)

# %% [markdown]
# ## 11 – T1w/MRSI registration: before vs after
#
# The downsampled T1w is masked with the filled water mask and then rigidly registered to the best-SNR MRSI map using ANTsPy. Because both images come from the same subject and session, a rigid transform is used.

# %%
print(f"Best-SNR metabolite used as registration target: {best_mrsi_label}")
plot_registration_comparison(
    t1w_ds_img,
    best_mrsi_img,
    mrsi_reg_ds_img,
    subj=SUBJ,
    ses=SES,
    mrsi_label=best_mrsi_label,
)
# Out:
# Best-SNR metabolite used as registration target: Gly

# %%
plot_registration_methods_comparison(
    t1w_ds_img,
    t1w_img,
    mrsi_reg_ds_img,
    mrsi_reg_fullres_img,
    subj=SUBJ,
    ses=SES,
    mrsi_label=best_mrsi_label,
)

# %% [markdown]
# ## 12 – Registration target comparison: best-SNR metabolite vs metabolite sum
#
# Two strategies for choosing the moving image to register to the downsampled T1w (rigid ANTs):
#
# - Left  image = best-SNR metabolite map
# - Right image = voxel-wise sum of all metabolite maps

# %%
plot_registration_target_comparison(
    t1w_ds_img,
    mrsi_reg_ds_img,
    mrsi_sum_reg_img,
    subj=SUBJ,
    ses=SES,
    bestsnr_label=best_mrsi_label,
)

# %%
cov_metrics = compare_registration_coverage(
    t1w_ds_img,
    water_mask,
    best_mrsi_img,
    mrsi_reg_ds_img,
    mrsi_sum_reg_img,
    reg1_transforms,
    reg3_transforms,
    subj=SUBJ,
    ses=SES,
    bestsnr_label=best_mrsi_label,
)
# Out:
# Metric                               Gly reg         Sum reg         Δ (a−b)
# ────────────────────────────────────────────────────────────────────────────
# Mean MRSI in-mask                     0.1279          0.2216         -0.0937
# Mean MRSI out-of-mask                 0.0000          0.0010         -0.0010
# In/Out SNR ratio              127938330.1735        220.0819  +127938110.0915
# % active voxels in-mask              51.5865         69.7442        -18.1577
# % active voxels out                   0.0000          0.4570         -0.4570

# %% [markdown]
# ## 13 – Metabolite sum: independent registration vs best-SNR transform reuse
#
# Two ways to bring the gly map into DS T1w space:
# - Left independent registration: the gly image is used as the moving image and ANTs solves a new rigid transform optimised specifically for it.
# - Right transform reuse: the rigid transform already solved for the sum image is applied directly to the sum, with no re optimisation.

# %%
plot_sum_registration_comparison(
    t1w_ds_img,
    mrsi_reg_ds_img,
    mrsi_gly_via_sum_img,
    subj=SUBJ,
    ses=SES,
    bestsnr_label=best_mrsi_label,
)
# Out:
#                                    mean in brain   CC with T1w
#   ----------------------------------------------------------
#   Gly — own transform                     0.1229       -0.0032
#   Gly — sum's transform                   0.1354       -0.0162

# %% [markdown]
# ## 14 – Coverage-based vs SNR-based registration: three-way comparison
#
# Three ways of placing the Gly map (best-SNR metabolite) and the best-coverage metabolite into DS T1w space, all compared side by side:

# %%
 
print(f"Best-coverage metabolite : {best_cov_label}  ({coverage_records[0]['n_voxels']} voxels)")
print(f"Best-SNR (Gly)           : {best_mrsi_label}  ({snr_records[0]['n_voxels']} voxels)")

plot_coverage_registration_comparison(
    t1w_ds_img,
    mrsi_cov_reg_img,
    mrsi_reg_ds_img,
    mrsi_gly_via_sum_img,
    subj=SUBJ,
    ses=SES,
    cov_label=best_cov_label,
    gly_label=best_mrsi_label,
)
# Out:
# Best-coverage metabolite : MM14addLip13aaddLip13baddMM12  (49036 voxels)
# Best-SNR (Gly)           : Gly  (38015 voxels)
#   Strategy                               Mean in brain   CC with T1w
#   ------------------------------------------------------------------
#   MM14addLip13aaddLip13baddMM12 — own transform          0.2212        0.0460
#   Gly — own transform                           0.1229       -0.0032
#   Gly — sum's transform                         0.1354       -0.0162

# %%
compare_registration_coverage(
    t1w_ds_img,
    water_mask,
    best_mrsi_img,
    mrsi_reg_ds_img,
    mrsi_cov_reg_img,
    reg1_transforms,
    reg6_transforms,
    subj=SUBJ,
    ses=SES,
    bestsnr_label=best_mrsi_label,
    sum_label=best_cov_label,
)
# Out:
# Metric                               Gly reg  MM14addLip13aaddLip13baddMM12         Δ (a−b)
# ───────────────────────────────────────────────────────────────────────────────────────────
# Mean MRSI in-mask                     0.1279          0.2262         -0.0982
# Mean MRSI out-of-mask                 0.0000          0.0016         -0.0016
# In/Out SNR ratio              127938330.1735        145.8468  +127938184.3267
# % active voxels in-mask              51.5865         69.0503        -17.4638
# % active voxels out                   0.0000          0.7246         -0.7246
# {'best_snr': {'mean_in': 0.12793833017349243,
#   'mean_out': 0.0,
#   'snr_ratio': 127938330.17349242,
#   'pct_active_in': 51.58652220809118,
#   'pct_active_out': 0.0},
#  'sum': {'mean_in': 0.22615373134613037,
#   'mean_out': 0.0015506247291341424,
#   'snr_ratio': 145.84675534334963,
#   'pct_active_in': 69.05034048650128,
#   'pct_active_out': 0.7245809459411368}}

# %% [markdown]
# ## 15 – Inverse registration: T1w to MRSI space
#
# Register the downsampled T1w (moving) to each MRSI map (fixed).

# %%
plot_inverse_registration_panels(
    mrsi_sum_img=sum_img,
    mrsi_gly_img=best_mrsi_img,
    t1w_via_sum_img=t1w_in_sum_img,
    t1w_via_gly_img=t1w_in_gly_img,
    t1w_via_sum_in_gly_img=t1w_via_sum_in_gly_img,
    subj=SUBJ,
    ses=SES,
    sum_label="Sum",
    gly_label=best_mrsi_label,
)

# %% [markdown]
# ## 16 – Weighted inverse registration: water signal as mask
#
# Supply the water signal image  as `mask` (fixed-image mask) in ANTs.
#
# Three comparisons on the MRSI background:
# - Left  T1w via no weighting mask inverse registration (Reg 8).
# - Right  T1w via water weighted inverse registration (Reg 10).

# %%
compare_inverse_registration_pair(
    best_mrsi_img,
    t1w_in_gly_img,
    t1w_in_gly_w_img,
    subj=SUBJ,
    ses=SES,
    label_left=f"{best_mrsi_label} (no mask)",
    label_right=f"{best_mrsi_label} (water weighted)",
)

# %%
compare_inverse_registration_pair(
    sum_img,
    t1w_in_sum_img,
    t1w_in_sum_w_img,
    subj=SUBJ,
    ses=SES,
    label_left="Sum (no mask)",
    label_right="Sum (water weighted)",
)

# %% [markdown]
# ## 17 – Water map alignment: naive vs Reg-11 reused vs Reg-18 direct
#
# Three-way comparison on the **water signal map** background (all T1w images in water-signal coordinate space):
#
# | Column | Method | Description |
# |--------|--------|-------------|
# | Left | Naive | Full-res T1w directly resampled to water grid — no registration |
# | Middle | Reg-11 reused | Reg-11 sum water-weighted transform (`inv_sum_w_transforms`) applied to T1w DS, resampled to water space — no re-optimisation |
# | Right | Reg-18 | T1w DS directly registered to water signal map (ANTs CLI rigid + water mask) |

# %%
# Left vs middle: naive resample vs Reg-11 sum transform reused
compare_inverse_registration_pair(
    water_img,
    t1w_ds_img,
    t1w_in_water_via17_img,
    subj=SUBJ,
    ses=SES,
    label_left="Full-res T1w naive resample (no reg)",
    label_right="T1w via Reg-11 sum transform (reused)",
)

# Middle vs right: Reg-11 reused vs Reg-18 direct
compare_inverse_registration_pair(
    water_img,
    t1w_in_water_via17_img,
    t1w_in_water_img,
    subj=SUBJ,
    ses=SES,
    label_left="T1w via Reg-11 sum transform (reused)",
    label_right="T1w via Reg-18 (direct to water, ANTs + mask)",
)

# %% [markdown]
# ## 18 – Skull-stripped T1w registered to MRSI space
#
# The downsampled T1w is first skull-stripped with FSL BET (`-f 0.3`), then
# rigidly registered to each MRSI map.  Removing non-brain tissue focuses ANTs'
# metric evaluation entirely on brain voxels, which often improves alignment.

# %%
# Gly: original vs skull-stripped
compare_inverse_registration_pair(
    best_mrsi_img,
    t1w_in_gly_img,
    t1w_brain_in_gly_img,
    subj=SUBJ,
    ses=SES,
    label_left=f"{best_mrsi_label} (no skull-strip)",
    label_right=f"{best_mrsi_label} (skull-stripped)",
)

# %%
# Sum: original vs skull-stripped
compare_inverse_registration_pair(
    sum_img,
    t1w_in_sum_img,
    t1w_brain_in_sum_img,
    subj=SUBJ,
    ses=SES,
    label_left="Sum (no skull-strip)",
    label_right="Sum (skull-stripped)",
)

# %% [markdown]
# ## 19 – Total pipeline: reoriented MRSI sum + skull-stripped T1w + water-weighted registration
#
# End-to-end best-practice pipeline combining all preprocessing steps:
#
# 1. Reorient all MRSI concentration maps to RAS canonical orientation (`nibabel.as_closest_canonical`).
# 2. Sum the reoriented maps → `AllMetabSumRAS` (maximises SNR, consistent voxel ordering).
# 3. Skull-strip the downsampled T1w with FSL BET (`-f 0.3`) to removes non-brain tissue.
# 4. Register skull-stripped T1w → reoriented sum using `antsRegistration` with the reoriented water signal as a fixed-image weight (`--masks`).
#
# The visualisation below compares:
# - Left skull-stripped T1w registered to the *original* (non-reoriented) sum (Reg 15).
# - Right  skull-stripped T1w registered to the *reoriented* sum (Reg 17, total pipeline).

# %% [markdown]
# ## 19b – Reg-17 total pipeline: effect of moving-mask choice (BET vs FreeSurfer)
#
# The Reg-17 pipeline registers the skull-stripped DS T1w to the reoriented MRSI sum using a water-signal fixed mask. The moving mask constrains which voxels of the T1w drive the optimisation. 2 variants are compared:
#
# | Column | Moving mask |
# |--------|-------------|
# | **BET** | FSL BET binary brain mask (DS)|
# | **FreeSurfer** | UNIDEND atlas brain mask (DS)|

# %%
plot_total_pipeline_comparison(
    sum_orig_img=sum_img,
    t1w_in_sum_orig_img=t1w_brain_in_sum_ras_img_freesurfer_mask,
    sum_ras_img=sum_ras_img,
    t1w_in_sum_ras_img=t1w_brain_in_sum_ras_img_bet_mask,
    subj=SUBJ,
    ses=SES,
)

# %%
# 19b inverse: MRSI sum in T1w space – BET mask (Reg-17a) vs FreeSurfer mask (Reg-17b)
# Background: DS T1w with skull (t1w_ds_img)
_sum_bet_t1w_path = os.path.join(OUTPUT_DIR, f"{SUBJ}_{SES}_desc-SumInT1wReg17BET_T1w.nii.gz")
_sum_fs_t1w_path  = os.path.join(OUTPUT_DIR, f"{SUBJ}_{SES}_desc-SumInT1wReg17FS_T1w.nii.gz")

sum_in_t1w_bet = apply_transform_to_metabolite(
    mrsi_path=SUM_RAS_PATH,
    transform_path=brain_sum_ras_transforms_bet_mask[0],
    t1w_ref_path=T1W_DS_PATH,
    out_path=_sum_bet_t1w_path,
    overwrite=False,
)
sum_in_t1w_fs = apply_transform_to_metabolite(
    mrsi_path=SUM_RAS_PATH,
    transform_path=brain_sum_ras_transforms_freesurfer_mask[0],
    t1w_ref_path=T1W_DS_PATH,
    out_path=_sum_fs_t1w_path,
    overwrite=False,
)
plot_registration_target_comparison(
    t1w_ds_img,
    sum_in_t1w_bet,
    sum_in_t1w_fs,
    subj=SUBJ,
    ses=SES,
    bestsnr_label="Sum  ←  Reg-17a inverse\n(BET mask, DS T1w background)",
    sum_label="Sum  ←  Reg-17b inverse\n(FreeSurfer mask, DS T1w background)",
)
# Out:
#   [reg17] AllMetabSumRAS: saved to sub-01_ses-01_desc-SumInT1wReg17BET_T1w.nii.gz
#   [reg17] AllMetabSumRAS: saved to sub-01_ses-01_desc-SumInT1wReg17FS_T1w.nii.gz

# %% [markdown]
# ## 20 – Final transform applied to all metabolites + registration quality metrics
#
# The **Reg-17 transform** (skull-stripped DS T1w → reoriented MRSI sum, water-weighted) is
# inverted and applied to every individual metabolite map, warping each one into T1w space
# (`antsApplyTransforms [transform.mat, 1]`).
#
# Three quality metrics are computed per metabolite in the **overlap region** (T1w brain > 0 ∩ MRSI signal > 0):
#
# | Metric | Interpretation |
# |--------|----------------|
# | **Coverage** | Fraction of T1w brain voxels that contain MRSI signal after registration |
# | **NCC** | Normalised cross correlation with T1w  higher = better spatial alignment |
# | **NMI** | Normalised mutual information  higher = more shared information with T1w |

# %%
plot_final_registration_mosaic(
    t1w_img=t1w_ds_img,
    reg_mrsi_imgs=final_reg_imgs_freesurfer_mask,
    subj=SUBJ,
    ses=SES,
)

# %%
# Axial mosaic: every metabolite overlaid on the T1w background
plot_final_registration_mosaic(
    t1w_img=t1w_ds_img,
    reg_mrsi_imgs=final_reg_imgs_bet_mask,
    subj=SUBJ,
    ses=SES,
)

# %%
plot_registration_metrics(metrics=metrics, subj=SUBJ, ses=SES)
# Out:
# Label                                 Coverage       NCC       NMI       SNR
# ───────────────────────────────────────────────────────────────────────────
# MM12                                     0.998    0.1252    0.0171     2.004
# Tau                                      0.997   -0.1162    0.0158     1.034
# minusCrCH2                               0.998   -0.1079    0.0167     0.971
# PCr                                      0.988   -0.1050    0.0164     0.984
# Scy                                      0.982   -0.1040    0.0059     0.582
# CraddPCr                                 0.999   -0.0971    0.0167     1.190
# Asc                                      0.973   -0.0958    0.0060     0.489
# GSH                                      0.996   -0.0945    0.0152     1.012
# Asp                                      0.999   -0.0911    0.0165     0.954
# InsaddGly                                0.999   -0.0896    0.0156     1.166
# Gln                                      0.981   -0.0821    0.0090     0.719
# Ins                                      0.998   -0.0814    0.0167     1.206
# PCh                                      0.989   -0.0813    0.0136     0.946
# GluaddGln                                0.999   -0.0695    0.0172     1.145
# Gly                                      0.990   -0.0680    0.0064     0.620
# GPCaddPCh                                0.999   -0.0657    0.0144     1.114
# Glu                                      0.998   -0.0648    0.0177     1.115
# Lac                                      0.744   -0.0647    0.0063     0.465
# Cr                                       0.998   -0.0620    0.0102     1.065
# Thr                                      0.395   -0.0600    0.0081     0.356
# Ala                                      0.718   -0.0584    0.0072     0.597
# NAA                                      0.998   -0.0583    0.0174     1.115
# MM17                                     0.999   -0.0514    0.0141     0.845
# Ser                                      0.979   -0.0512    0.0065     0.671
# GABA                                     0.999   -0.0489    0.0155     0.980
# 2HG                                      0.622   -0.0454    0.0081     0.422
# NAAaddNAAG                               0.999   -0.0422    0.0179     1.155
# MM14addLip13aaddLip13baddMM12            0.999    0.0316    0.0181     1.428
# WaterSignal                              1.000    0.0228    0.0143     6.154
# Lip13a                                   0.481   -0.0209    0.0054     0.291
# Glc                                      0.935   -0.0193    0.0082     0.635
# Lip13b                                   0.497    0.0188    0.0102     0.555
# MM20addLip20                             0.601    0.0170    0.0079     0.528
# NAAG                                     0.995    0.0139    0.0147     1.072
# GPC                                      0.987   -0.0108    0.0111     1.027
# Lip13aaddLip13b                          0.698   -0.0096    0.0052     0.471
# MM14                                     0.998    0.0070    0.0175     1.107
# Lip20                                    0.499    0.0044    0.0075     0.458
# MM20                                     0.489   -0.0005    0.0088     0.584

# %%
# 20b – Pipeline comparison: BET mask vs FreeSurfer mask (Reg-17a vs Reg-17b)

# Compare NCC, NMI and SNR metrics for every metabolite between the two
# final pipelines. Lines in the scatter panel connect the same metabolite
# across pipelines; the delta bar chart shows FreeSurfer − BET so that
# positive values mean the FreeSurfer mask produced better alignment.
plot_pipeline_metrics_comparison(
    metrics_a=metrics,
    metrics_b=metrics_freesurfer_mask,
    label_a="BET mask (Reg-17a)",
    label_b="FreeSurfer mask (Reg-17b)",
    subj=SUBJ,
    ses=SES,
)
# Out:
# Label                                   NCC(A)     NCC(B)      ΔNCC     NMI(A)     NMI(B)      ΔNMI    SNR(A)    SNR(B)
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# MM12                                    0.1252     0.1252   +0.0000     0.0171     0.0171   +0.0000     2.004     2.004
# Tau                                    -0.1162    -0.1162   +0.0000     0.0158     0.0158   +0.0000     1.034     1.034
# minusCrCH2                             -0.1079    -0.1079   +0.0000     0.0167     0.0167   +0.0000     0.971     0.971
# PCr                                    -0.1050    -0.1050   +0.0000     0.0164     0.0164   +0.0000     0.984     0.984
# Scy                                    -0.1040    -0.1040   +0.0000     0.0059     0.0059   +0.0000     0.582     0.582
# CraddPCr                               -0.0971    -0.0971   +0.0000     0.0167     0.0167   +0.0000     1.190     1.190
# Asc                                    -0.0958    -0.0958   +0.0000     0.0060     0.0060   +0.0000     0.489     0.489
# GSH                                    -0.0945    -0.0945   +0.0000     0.0152     0.0152   +0.0000     1.012     1.012
# Asp                                    -0.0911    -0.0911   +0.0000     0.0165     0.0165   +0.0000     0.954     0.954
# InsaddGly                              -0.0896    -0.0896   +0.0000     0.0156     0.0156   +0.0000     1.166     1.166
# Gln                                    -0.0821    -0.0821   +0.0000     0.0090     0.0090   +0.0000     0.719     0.719
# Ins                                    -0.0814    -0.0814   +0.0000     0.0167     0.0167   +0.0000     1.206     1.206
# PCh                                    -0.0813    -0.0813   +0.0000     0.0136     0.0136   +0.0000     0.946     0.946
# GluaddGln                              -0.0695    -0.0695   +0.0000     0.0172     0.0172   +0.0000     1.145     1.145
# Gly                                    -0.0680    -0.0680   +0.0000     0.0064     0.0064   +0.0000     0.620     0.620
# GPCaddPCh                              -0.0657    -0.0657   +0.0000     0.0144     0.0144   +0.0000     1.114     1.114
# Glu                                    -0.0648    -0.0648   +0.0000     0.0177     0.0177   +0.0000     1.115     1.115
# Lac                                    -0.0647    -0.0647   +0.0000     0.0063     0.0063   +0.0000     0.465     0.465
# Cr                                     -0.0620    -0.0620   +0.0000     0.0102     0.0102   +0.0000     1.065     1.065
# Thr                                    -0.0600    -0.0600   +0.0000     0.0081     0.0081   +0.0000     0.356     0.356
# Ala                                    -0.0584    -0.0584   +0.0000     0.0072     0.0072   +0.0000     0.597     0.597
# NAA                                    -0.0583    -0.0583   +0.0000     0.0174     0.0174   +0.0000     1.115     1.115
# MM17                                   -0.0514    -0.0514   +0.0000     0.0141     0.0141   +0.0000     0.845     0.845
# Ser                                    -0.0512    -0.0512   +0.0000     0.0065     0.0065   +0.0000     0.671     0.671
# GABA                                   -0.0489    -0.0489   +0.0000     0.0155     0.0155   +0.0000     0.980     0.980
# 2HG                                    -0.0454    -0.0454   +0.0000     0.0081     0.0081   +0.0000     0.422     0.422
# NAAaddNAAG                             -0.0422    -0.0422   +0.0000     0.0179     0.0179   +0.0000     1.155     1.155
# MM14addLip13aaddLip13baddMM12           0.0316     0.0316   +0.0000     0.0181     0.0181   +0.0000     1.428     1.428
# WaterSignal                             0.0228     0.0228   +0.0000     0.0143     0.0143   +0.0000     6.154     6.154
# Lip13a                                 -0.0209    -0.0209   +0.0000     0.0054     0.0054   +0.0000     0.291     0.291
# Glc                                    -0.0193    -0.0193   +0.0000     0.0082     0.0082   +0.0000     0.635     0.635
# Lip13b                                  0.0188     0.0188   +0.0000     0.0102     0.0102   +0.0000     0.555     0.555
# MM20addLip20                            0.0170     0.0170   +0.0000     0.0079     0.0079   +0.0000     0.528     0.528
# NAAG                                    0.0139     0.0139   +0.0000     0.0147     0.0147   +0.0000     1.072     1.072
# GPC                                    -0.0108    -0.0108   +0.0000     0.0111     0.0111   +0.0000     1.027     1.027
# Lip13aaddLip13b                        -0.0096    -0.0096   +0.0000     0.0052     0.0052   +0.0000     0.471     0.471
# MM14                                    0.0070     0.0070   +0.0000     0.0175     0.0175   +0.0000     1.107     1.107
# Lip20                                   0.0044     0.0044   +0.0000     0.0075     0.0075   +0.0000     0.458     0.458
# MM20                                   -0.0005    -0.0005   +0.0000     0.0088     0.0088   +0.0000     0.584     0.584

# %%
plot_mrsi_sum_mask_contours(
    sum_img=sum_img,
    water_mask_img=water_mask_img,
    bet_mask_img=bet_mask_reg_img,
    freesurfer_mask_img=freesurfer_mask_reg_img,
    subj=SUBJ,
    ses=SES,
)

# %%
plot_segmentation(
    t1w_img=t1w_brain_img,
    seg_imgs=seg_imgs,
    subj=SUBJ,
    ses=SES,
)
# Out:
# /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/plot_utils.py:1763: UserWarning: kwargs['alpha']=0.55 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   plotting.plot_stat_map(
# /Users/user/FCBG_project_Connectome_registraction/Code/FCBG_project_Connectome_registraction/plot_utils.py:1808: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Tissue               Mean PVE   Volume (mL)
# ────────────────────────────────────────────
#   CSF                   0.594        170.9 mL
#   Grey Matter           0.718        525.6 mL
#   White Matter          0.851        459.4 mL

# %%
plot_mask_coverage_comparaison(
        bet_mask_img=bet_mask_reg_img,
        water_mask_img=water_mask_img,
        extra_mask_img=freesurfer_mask_reg_img,
        t1w_ds_img=t1w_ds_img,
        active_mask_name=T1W_BRAIN_MASK_DS_NAME)
# Out:
# ────────────────────────────────────────────────────
#   Mask comparison (MRSI grid)
# ────────────────────────────────────────────────────
#   BET mask volume      :   1125.6 mL  ( 42838 vox)
#   Water mask volume    :   1686.2 mL  ( 64170 vox)
#   FREESURFER mask volume :   1356.5 mL  ( 51624 vox)
# ────────────────────────────────────────────────────
#   BET ∩ Water          :   1118.4 mL  ( 42562 vox)
#   BET-only voxels      :      7.3 mL  (   276 vox)
#   Water-only voxels    :    567.8 mL  ( 21608 vox)
#   Dice  BET/Water      : 0.7955  Jaccard: 0.6604
#   Dice  BET/FREESURFER : 0.9066  Jaccard: 0.8292
#   Dice  Water/FREESURFER : 0.8675  Jaccard: 0.7660
#   All-3 intersection   :   1117.9 mL  ( 42545 vox)
#   FREESURFERmask-only voxels :     29.5 mL  (  1124 vox)
#   BET ≡ Water          : False
# ────────────────────────────────────────────────────
#
#   ACTIVE mask for Reg 18 : sub-01_ses-01_acq-MRSIres_desc-BrainMask_T1w.nii.gz

# %%
#from main import atlas_imgs
#plot_atlas_segmentation(
#    t1w_img=t1w_brain_img,
#    atlas_imgs=atlas_imgs,
#    subj=SUBJ,
#    ses=SES)
